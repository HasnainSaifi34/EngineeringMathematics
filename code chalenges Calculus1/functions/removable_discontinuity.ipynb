# %%
import numpy as np
import sympy as sym;
import matplotlib.pyplot as plt;

# %% [markdown]
# ------
#
# f(X) = {
#     sin(pi*x)+x^2 for (x!=0)
#     pi        for (x==0)
# }
#
#
# ------

# %%
from sympy.abc import x;


# piece1 = sym.sin(sym.pi*x)+x**2

# piece2 = sym.pi;


# s_y = sym.Piecewise(
#     (piece1,x!=0),
#     (piece2,sym.Eq(x,0))
# )
xDomain = [-1,+2]
steps=5000
tolerence = 1e-10
xx = np.linspace(xDomain[0],xDomain[1],steps)


y = np.sin(np.pi*xx)+xx**2;

# y[xx<tolerence]==np.pi

y[np.argmin(np.abs(xx))]==np.pi  # we can remove the discontinuity

plt.plot(xx,y,"o")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 26
#      23 y[np.argmin(np.abs(xx))]==np.pi
#      25 plt.plot(xx,y,"o")
# ---> 26 y[1e-10]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
